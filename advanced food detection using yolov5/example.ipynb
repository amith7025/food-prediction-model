# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path='best.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\amith/.cache\torch\hub\master.zip
# YOLOv5  2023-9-8 Python-3.11.4 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20897385 parameters, 0 gradients, 48.0 GFLOPs
# Adding AutoShape...

# %%
model.parameters()
# Out:
# <generator object Module.parameters at 0x000002D349290200>

# %%
img = 'images.jpg'

# %%
results = model(img)
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 183x275 1 Fries, 1 burger
# Speed: 25.7ms pre-process, 924.2ms inference, 1.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results =
