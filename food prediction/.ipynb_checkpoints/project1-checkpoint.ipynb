# %%
import torch

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cpu'

# %%
from pathlib import Path

# %%
data_path = Path('data/')

# %%
import requests
import os

# %%
download_dir = data_path  # Replace with your desired directory.
os.makedirs(download_dir, exist_ok=True)

# %%
url = "https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip"

# %%
response = requests.get(url)

# Check if the request was successful (status code 200).
if response.status_code == 200:
    # Specify the file path to save the downloaded dataset.
    dataset_path = os.path.join(download_dir, "dataset.zip")

    # Write the content of the response to the file.
    with open(dataset_path, 'wb') as f:
        f.write(response.content)
    print("Dataset downloaded successfully.")
else:
    print("Failed to download dataset. Status code:", response.status_code)
# Out:
# Dataset downloaded successfully.

# %%
import zipfile

# %%
# Extract the dataset if it's in ZIP format.
if dataset_path.endswith(".zip"):
    with zipfile.ZipFile(dataset_path, 'r') as zip_ref:
        zip_ref.extractall(download_dir)
    print("Dataset extracted successfully.")
# Out:
# Dataset extracted successfully.

# %%
train_dir = data_path / "train"
test_dir = data_path / "test"

# %%
import random
import PIL
from PIL import Image

# %%
train_image_list = list(train_dir.glob("*/*.jpg"))
train_image_list
# Out:
# [PosixPath('data/train/sushi/2641778.jpg'),
#  PosixPath('data/train/sushi/385154.jpg'),
#  PosixPath('data/train/sushi/1571146.jpg'),
#  PosixPath('data/train/sushi/2980779.jpg'),
#  PosixPath('data/train/sushi/794647.jpg'),
#  PosixPath('data/train/sushi/2021685.jpg'),
#  PosixPath('data/train/sushi/2175561.jpg'),
#  PosixPath('data/train/sushi/1221830.jpg'),
#  PosixPath('data/train/sushi/3353428.jpg'),
#  PosixPath('data/train/sushi/3360232.jpg'),
#  PosixPath('data/train/sushi/3004029.jpg'),
#  PosixPath('data/train/sushi/169392.jpg'),
#  PosixPath('data/train/sushi/2004525.jpg'),
#  PosixPath('data/train/sushi/710379.jpg'),
#  PosixPath('data/train/sushi/17704.jpg'),
#  PosixPath('data/train/sushi/542188.jpg'),
#  PosixPath('data/train/sushi/3360207.jpg'),
#  PosixPath('data/train/sushi/2813454.jpg'),
#  PosixPath('data/train/sushi/2797464.jpg'),
#  PosixPath('data/train/sushi/1138695.jpg'),
#  PosixPath('data/train/sushi/3107839.jpg'),
#  PosixPath('data/train/sushi/1214108.jpg'),
#  PosixPath('data/train/sushi/3737197.jpg'),
#  PosixPath('data/train/sushi/1070104.jpg'),
#  PosixPath('data/train/sushi/3579071.jpg'),
#  PosixPath('data/train/sushi/843815.jpg'),
#  PosixPath('data/train/sushi/3081701.jpg'),
#  PosixPath('data/train/sushi/200025.jpg'),
#  PosixPath('data/train/sushi/2873571.jpg'),
#  PosixPath('data/train/sushi/2492146.jpg'),
#  PosixPath('data/train/sushi/748830.jpg'),
#  PosixPath('data/train/sushi/170385.jpg'),
#  PosixPath('data/train/sushi/821108.jpg'),
#  PosixPath('data/train/sushi/121940.jpg'),
#  PosixPath('data/train/sushi/3251688.jpg'),
#  PosixPath('data/train/sushi/1129338.jpg'),
#  PosixPath('data/train/sushi/2574453.jpg'),
#  PosixPath('data/train/sushi/2590819.jpg'),
#  PosixPath('data/train/sushi/1209865.jpg'),
#  PosixPath('data/train/sushi/2120573.jpg'),
#  PosixPath('data/train/sushi/3426958.jpg'),
#  PosixPath('data/train/sushi/2017378.jpg'),
#  PosixPath('data/train/sushi/390178.jpg'),
#  PosixPath('data/train/sushi/773725.jpg'),
#  PosixPath('data/train/sushi/1551817.jpg'),
#  PosixPath('data/train/sushi/1280119.jpg'),
#  PosixPath('data/train/sushi/2323548.jpg'),
#  PosixPath('data/train/sushi/1232045.jpg'),
#  PosixPath('data/train/sushi/2871052.jpg'),
#  PosixPath('data/train/sushi/148799.jpg'),
#  PosixPath('data/train/sushi/14046.jpg'),
#  PosixPath('data/train/sushi/2674024.jpg'),
#  PosixPath('data/train/sushi/700405.jpg'),
#  PosixPath('data/train/sushi/424994.jpg'),
#  PosixPath('data/train/sushi/765684.jpg'),
#  PosixPath('data/train/sushi/1957449.jpg'),
#  PosixPath('data/train/sushi/929471.jpg'),
#  PosixPath('data/train/sushi/2267190.jpg'),
#  PosixPath('data/train/sushi/93139.jpg'),
#  PosixPath('data/train/sushi/497686.jpg'),
#  PosixPath('data/train/sushi/2019344.jpg'),
#  PosixPath('data/train/sushi/2021381.jpg'),
#  PosixPath('data/train/sushi/2720223.jpg'),
#  PosixPath('data/train/sushi/1552504.jpg'),
#  PosixPath('data/train/sushi/377047.jpg'),
#  PosixPath('data/train/sushi/1615453.jpg'),
#  PosixPath('data/train/sushi/840444.jpg'),
#  PosixPath('data/train/sushi/268990.jpg'),
#  PosixPath('data/train/sushi/307738.jpg'),
#  PosixPath('data/train/sushi/686426.jpg'),
#  PosixPath('data/train/sushi/1575445.jpg'),
#  PosixPath('data/train/sushi/855721.jpg'),
#  PosixPath('data/train/steak/914570.jpg'),
#  PosixPath('data/train/steak/1413972.jpg'),
#  PosixPath('data/train/steak/2629750.jpg'),
#  PosixPath('data/train/steak/2017387.jpg'),
#  PosixPath('data/train/steak/2880035.jpg'),
#  PosixPath('data/train/steak/3727491.jpg'),
#  PosixPath('data/train/steak/231296.jpg'),
#  PosixPath('data/train/steak/225990.jpg'),
#  PosixPath('data/train/steak/2087958.jpg'),
#  PosixPath('data/train/steak/167069.jpg'),
#  PosixPath('data/train/steak/1257104.jpg'),
#  PosixPath('data/train/steak/1225762.jpg'),
#  PosixPath('data/train/steak/1937872.jpg'),
#  PosixPath('data/train/steak/3142045.jpg'),
#  PosixPath('data/train/steak/560503.jpg'),
#  PosixPath('data/train/steak/3518960.jpg'),
#  PosixPath('data/train/steak/3577618.jpg'),
#  PosixPath('data/train/steak/256592.jpg'),
#  PosixPath('data/train/steak/1849463.jpg'),
#  PosixPath('data/train/steak/1615395.jpg'),
#  PosixPath('data/train/steak/1976160.jpg'),
#  PosixPath('data/train/steak/830007.jpg'),
#  PosixPath('data/train/steak/234626.jpg'),
#  PosixPath('data/train/steak/1787505.jpg'),
#  PosixPath('data/train/steak/2614189.jpg'),
#  PosixPath('data/train/steak/2324994.jpg'),
#  PosixPath('data/train/steak/1966300.jpg'),
#  PosixPath('data/train/steak/735441.jpg'),
#  PosixPath('data/train/steak/482022.jpg'),
#  PosixPath('data/train/steak/3245622.jpg'),
#  PosixPath('data/train/steak/2881783.jpg'),
#  PosixPath('data/train/steak/2878151.jpg'),
#  PosixPath('data/train/steak/75537.jpg'),
#  PosixPath('data/train/steak/2648423.jpg'),
#  PosixPath('data/train/steak/2979061.jpg'),
#  PosixPath('data/train/steak/1264154.jpg'),
#  PosixPath('data/train/steak/165639.jpg'),
#  PosixPath('data/train/steak/1761285.jpg'),
#  PosixPath('data/train/steak/2129685.jpg'),
#  PosixPath('data/train/steak/2614649.jpg'),
#  PosixPath('data/train/steak/214320.jpg'),
#  PosixPath('data/train/steak/922752.jpg'),
#  PosixPath('data/train/steak/2603058.jpg'),
#  PosixPath('data/train/steak/339891.jpg'),
#  PosixPath('data/train/steak/2287136.jpg'),
#  PosixPath('data/train/steak/1839481.jpg'),
#  PosixPath('data/train/steak/1621763.jpg'),
#  PosixPath('data/train/steak/443210.jpg'),
#  PosixPath('data/train/steak/1736968.jpg'),
#  PosixPath('data/train/steak/1624747.jpg'),
#  PosixPath('data/train/steak/3142674.jpg'),
#  PosixPath('data/train/steak/1647351.jpg'),
#  PosixPath('data/train/steak/1598345.jpg'),
#  PosixPath('data/train/steak/2254705.jpg'),
#  PosixPath('data/train/steak/937133.jpg'),
#  PosixPath('data/train/steak/97656.jpg'),
#  PosixPath('data/train/steak/2606444.jpg'),
#  PosixPath('data/train/steak/2628106.jpg'),
#  PosixPath('data/train/steak/1961025.jpg'),
#  PosixPath('data/train/steak/3074367.jpg'),
#  PosixPath('data/train/steak/2561199.jpg'),
#  PosixPath('data/train/steak/3857508.jpg'),
#  PosixPath('data/train/steak/239025.jpg'),
#  PosixPath('data/train/steak/3727036.jpg'),
#  PosixPath('data/train/steak/461689.jpg'),
#  PosixPath('data/train/steak/2222018.jpg'),
#  PosixPath('data/train/steak/176508.jpg'),
#  PosixPath('data/train/steak/2163079.jpg'),
#  PosixPath('data/train/steak/100135.jpg'),
#  PosixPath('data/train/steak/2013535.jpg'),
#  PosixPath('data/train/steak/1382427.jpg'),
#  PosixPath('data/train/steak/2825100.jpg'),
#  PosixPath('data/train/steak/2707522.jpg'),
#  PosixPath('data/train/steak/421476.jpg'),
#  PosixPath('data/train/steak/355715.jpg'),
#  PosixPath('data/train/pizza/138855.jpg'),
#  PosixPath('data/train/pizza/1899785.jpg'),
#  PosixPath('data/train/pizza/2285942.jpg'),
#  PosixPath('data/train/pizza/667309.jpg'),
#  PosixPath('data/train/pizza/320570.jpg'),
#  PosixPath('data/train/pizza/2451169.jpg'),
#  PosixPath('data/train/pizza/853441.jpg'),
#  PosixPath('data/train/pizza/68684.jpg'),
#  PosixPath('data/train/pizza/220190.jpg'),
#  PosixPath('data/train/pizza/2291093.jpg'),
#  PosixPath('data/train/pizza/3530210.jpg'),
#  PosixPath('data/train/pizza/1660415.jpg'),
#  PosixPath('data/train/pizza/3699992.jpg'),
#  PosixPath('data/train/pizza/1947572.jpg'),
#  PosixPath('data/train/pizza/702165.jpg'),
#  PosixPath('data/train/pizza/3281494.jpg'),
#  PosixPath('data/train/pizza/2330965.jpg'),
#  PosixPath('data/train/pizza/2785084.jpg'),
#  PosixPath('data/train/pizza/3109486.jpg'),
#  PosixPath('data/train/pizza/2428085.jpg'),
#  PosixPath('data/train/pizza/2800325.jpg'),
#  PosixPath('data/train/pizza/1968947.jpg'),
#  PosixPath('data/train/pizza/1654444.jpg'),
#  PosixPath('data/train/pizza/3589437.jpg'),
#  PosixPath('data/train/pizza/2121603.jpg'),
#  PosixPath('data/train/pizza/29417.jpg'),
#  PosixPath('data/train/pizza/1033251.jpg'),
#  PosixPath('data/train/pizza/765799.jpg'),
#  PosixPath('data/train/pizza/715169.jpg'),
#  PosixPath('data/train/pizza/618348.jpg'),
#  PosixPath('data/train/pizza/764429.jpg'),
#  PosixPath('data/train/pizza/3338774.jpg'),
#  PosixPath('data/train/pizza/928670.jpg'),
#  PosixPath('data/train/pizza/2576168.jpg'),
#  PosixPath('data/train/pizza/3821701.jpg'),
#  PosixPath('data/train/pizza/2885050.jpg'),
#  PosixPath('data/train/pizza/244505.jpg'),
#  PosixPath('data/train/pizza/786995.jpg'),
#  PosixPath('data/train/pizza/739735.jpg'),
#  PosixPath('data/train/pizza/1285298.jpg'),
#  PosixPath('data/train/pizza/2228322.jpg'),
#  PosixPath('data/train/pizza/1044789.jpg'),
#  PosixPath('data/train/pizza/300869.jpg'),
#  PosixPath('data/train/pizza/38349.jpg'),
#  PosixPath('data/train/pizza/1649276.jpg'),
#  PosixPath('data/train/pizza/1008844.jpg'),
#  PosixPath('data/train/pizza/3505182.jpg'),
#  PosixPath('data/train/pizza/2992084.jpg'),
#  PosixPath('data/train/pizza/2154394.jpg'),
#  PosixPath('data/train/pizza/393658.jpg'),
#  PosixPath('data/train/pizza/3018077.jpg'),
#  PosixPath('data/train/pizza/1572608.jpg'),
#  PosixPath('data/train/pizza/2569760.jpg'),
#  PosixPath('data/train/pizza/1089334.jpg'),
#  PosixPath('data/train/pizza/1633289.jpg'),
#  PosixPath('data/train/pizza/1524655.jpg'),
#  PosixPath('data/train/pizza/2821048.jpg'),
#  PosixPath('data/train/pizza/2702825.jpg'),
#  PosixPath('data/train/pizza/2687575.jpg'),
#  PosixPath('data/train/pizza/2811032.jpg'),
#  PosixPath('data/train/pizza/218711.jpg'),
#  PosixPath('data/train/pizza/3860002.jpg'),
#  PosixPath('data/train/pizza/2190018.jpg'),
#  PosixPath('data/train/pizza/2382016.jpg'),
#  PosixPath('data/train/pizza/12301.jpg'),
#  PosixPath('data/train/pizza/2924941.jpg'),
#  PosixPath('data/train/pizza/2885796.jpg'),
#  PosixPath('data/train/pizza/3269634.jpg'),
#  PosixPath('data/train/pizza/2026009.jpg'),
#  PosixPath('data/train/pizza/2493954.jpg'),
#  PosixPath('data/train/pizza/1412034.jpg'),
#  PosixPath('data/train/pizza/2426686.jpg'),
#  PosixPath('data/train/pizza/3441394.jpg'),
#  PosixPath('data/train/pizza/741883.jpg'),
#  PosixPath('data/train/pizza/2760984.jpg'),
#  PosixPath('data/train/pizza/1105700.jpg'),
#  PosixPath('data/train/pizza/3196721.jpg'),
#  PosixPath('data/train/pizza/5764.jpg')]

# %%
random_image = random.choice(train_image_list)
img = Image.open(random_image)
print(f"image shape:{img.size}")
img
# Out:
# image shape:(512, 512)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
image_as_array = np.array(img)
plt.imshow(image_as_array)
plt.axis(False)
plt.show()

# %%
image_list = random.sample(train_image_list,k=5)
image_list
# Out:
# [PosixPath('data/train/steak/1966300.jpg'),
#  PosixPath('data/train/pizza/3860002.jpg'),
#  PosixPath('data/train/pizza/3821701.jpg'),
#  PosixPath('data/train/sushi/1129338.jpg'),
#  PosixPath('data/train/sushi/497686.jpg')]

# %%
image_as_array
# Out:
# array([[[ 67,  51,  38],
#         [ 67,  51,  38],
#         [ 65,  47,  33],
#         ...,
#         [ 49,  33,   8],
#         [ 47,  29,   7],
#         [ 45,  27,   5]],
#
#        [[ 65,  49,  36],
#         [ 66,  50,  37],
#         [ 65,  47,  33],
#         ...,
#         [ 51,  35,  10],
#         [ 50,  32,  10],
#         [ 48,  30,   8]],
#
#        [[ 60,  44,  31],
#         [ 62,  46,  33],
#         [ 63,  45,  31],
#         ...,
#         [ 53,  37,  12],
#         [ 53,  35,  13],
#         [ 52,  34,  12]],
#
#        ...,
#
#        [[191, 147,  38],
#         [183, 141,  33],
#         [185, 141,  42],
#         ...,
#         [208, 231, 202],
#         [210, 234, 202],
#         [211, 235, 203]],
#
#        [[207, 161,  50],
#         [182, 138,  31],
#         [176, 130,  32],
#         ...,
#         [209, 232, 203],
#         [207, 231, 199],
#         [207, 231, 199]],
#
#        [[210, 164,  52],
#         [191, 144,  36],
#         [181, 135,  37],
#         ...,
#         [210, 233, 204],
#         [205, 229, 197],
#         [203, 227, 195]]], dtype=uint8)

# %%
import torchvision
from torchvision import transforms

# %%
train_transforms = transforms.Compose([
    transforms.Resize(size=(64,64)),
    transforms.ColorJitter(
    brightness=0.2,
    contrast=0.2,
    saturation=0.2,
    hue=0.1
    ),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406],  # Mean values for each channel
                         #std=[0.229, 0.224, 0.225])
])

# %%
test_transforms = transforms.Compose([
    transforms.Resize(size=(64,64)),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406],  # Mean values for each channel
                         #std=[0.229, 0.224, 0.225])
])

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

# %%
train_data = datasets.ImageFolder(
    root=train_dir,
    transform=train_transforms,
    target_transform=None
)

# %%
test_data = datasets.ImageFolder(
    root=test_dir,
    transform=test_transforms,
    target_transform=None
)

# %%
train_data,test_data
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 225
#      Root location: data/train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                 ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#                 ToTensor()
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 75
#      Root location: data/test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(64, 64), interpolation=bilinear, max_size=None, antialias=warn)
#                 ToTensor()
#             ))

# %%
train_image,label = train_data[0]
plt.imshow(train_image.permute(1,2,0))
plt.title(label)
plt.axis(False)
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
train_image
# Out:
# tensor([[[0.0863, 0.0941, 0.1020,  ..., 0.0471, 0.0549, 0.0784],
#          [0.1059, 0.1059, 0.1059,  ..., 0.0471, 0.0549, 0.0667],
#          [0.1059, 0.1059, 0.1059,  ..., 0.0353, 0.0471, 0.0549],
#          ...,
#          [0.1765, 0.1490, 0.1529,  ..., 0.0863, 0.0588, 0.0627],
#          [0.1725, 0.1608, 0.1608,  ..., 0.0627, 0.0431, 0.0392],
#          [0.1608, 0.1647, 0.1686,  ..., 0.0549, 0.0353, 0.0353]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0196, 0.0118, 0.0196],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0196, 0.0118, 0.0196],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0196, 0.0196, 0.0118],
#          ...,
#          [0.2431, 0.2431, 0.2549,  ..., 0.1216, 0.0980, 0.0941],
#          [0.2314, 0.2431, 0.2549,  ..., 0.0902, 0.0784, 0.0667],
#          [0.2275, 0.2392, 0.2471,  ..., 0.0745, 0.0627, 0.0627]],
#
#         [[0.0431, 0.0471, 0.0510,  ..., 0.0549, 0.0627, 0.0784],
#          [0.0510, 0.0510, 0.0510,  ..., 0.0549, 0.0588, 0.0667],
#          [0.0431, 0.0431, 0.0431,  ..., 0.0471, 0.0549, 0.0627],
#          ...,
#          [0.1373, 0.1255, 0.1333,  ..., 0.1216, 0.0784, 0.0824],
#          [0.1373, 0.1294, 0.1333,  ..., 0.0745, 0.0549, 0.0510],
#          [0.1294, 0.1294, 0.1373,  ..., 0.0510, 0.0392, 0.0510]]])

# %%
classes = train_data.classes
classes
# Out:
# ['pizza', 'steak', 'sushi']

# %%
len(train_data),len(test_data)
# Out:
# (225, 75)

# %%
BATCH_SIZE = 8
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_data,batch_size=BATCH_SIZE,shuffle=False)

# %%
train_loader,test_loader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7c30c4c2b190>,
#  <torch.utils.data.dataloader.DataLoader at 0x7c30c4c29f90>)

# %%
image,label = next(iter(train_loader))
image.shape,label
# Out:
# (torch.Size([8, 3, 64, 64]), tensor([0, 2, 0, 0, 2, 0, 2, 1]))

# %%
import torch.nn as nn

# %%
from torch.nn.modules.conv import Conv2d
class FoodClassification(nn.Module):
  def __init__(self,input_shape=3,output_shape=len(classes)):
    super().__init__()

    self.Conv_blk_1 = nn.Sequential(
        nn.Conv2d(3,32,kernel_size=2,stride=1),
        nn.ReLU(),
        nn.Dropout2d(0.5),
        nn.MaxPool2d(kernel_size=2,stride=1),
        nn.Conv2d(32,16,kernel_size=2,stride=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2,stride=2)
    )
    self.avgpool = nn.AvgPool2d(kernel_size=2)
    self.classifier = nn.Sequential(
        nn.Dropout(),
        nn.Linear(16*15*15,32),
        nn.ReLU(),
        nn.Dropout(),
        nn.Linear(32,32),
        nn.ReLU(),
        nn.Linear(32,output_shape)
    )
  def forward(self, x):
        x = self.Conv_blk_1(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
torch.manual_seed(42)

model = FoodClassification().to(device)

# %%
image = torch.randn(8,3,64,64)
model(image.to(device))
# Out:
# tensor([[-0.0606,  0.2138,  0.0153],
#         [-0.0805,  0.0584, -0.0823],
#         [-0.1417, -0.0118, -0.2302],
#         [-0.0151,  0.1834, -0.1482],
#         [-0.0425,  0.0768, -0.0251],
#         [-0.1823,  0.1796, -0.0256],
#         [-0.0586,  0.1711, -0.1421],
#         [ 0.0840,  0.1539, -0.1318]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(),lr=0.001,weight_decay=0.001)

# %%
def train_step(model,dataloader,loss_fn,optimizer,device):
  train_loss = 0
  model.train()
  for batch in dataloader:
    optimizer.zero_grad()
    input,target = batch
    input,target = input.to(device),target.to(device)
    output = model(input)
    loss = loss_fn(output,target)
    loss.backward()
    optimizer.step()
    train_loss += loss.data.item()
  train_loss /= len(dataloader)
  return train_loss

# %%
def test_step(model,dataloader,loss_fn,device):
  test_loss = 0
  model.eval()
  for batch in dataloader:
    input,target = batch
    input,target = input.to(device),target.to(device)
    output = model(input)
    loss = loss_fn(output,target)
    test_loss += loss.data.item()
  test_loss /= len(dataloader)
  return test_loss

# %%
from tqdm.auto import tqdm

# %%
epochs = 50

# %%
for epoch in tqdm(range(epochs)):
  train_loss = train_step(
      model=model,
      dataloader=train_loader,
      loss_fn=loss_fn,
      optimizer=optimizer,
      device=device
  )
  test_loss = test_step(
      model=model,
      dataloader=test_loader,
      loss_fn=loss_fn,
      device=device
  )
  print(f"train loss:{train_loss}  test loss:{test_loss}")
  if test_loss <= 0.92:
    break
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# train loss:1.102440591516166  test loss:1.1008222699165344
# train loss:1.090055983642052  test loss:1.0987495183944702
# train loss:1.0411241732794663  test loss:1.0642613291740417
# train loss:0.9868607356630522  test loss:1.0142329156398773
# train loss:0.9412756459466343  test loss:0.9960982024669647
# train loss:0.9208749964319426  test loss:1.0107949793338775
# train loss:0.8998363696295639  test loss:1.0138415336608886
# train loss:0.9122720257989292  test loss:0.992696362733841
# train loss:0.8518514181005543  test loss:0.9763261795043945
# train loss:0.8259669768399206  test loss:0.9834922671318054
# train loss:0.8081533395010849  test loss:0.9626502275466919
# train loss:0.7730686487308864  test loss:0.9757304430007935
# train loss:0.7792040870107454  test loss:0.9656285464763641
# train loss:0.7580706692975143  test loss:0.977248364686966
# train loss:0.7315666891377548  test loss:0.9702645838260651
# train loss:0.7941144530115456  test loss:0.9547827482223511
# train loss:0.808231181111829  test loss:0.9801210582256317
# train loss:0.6639840841566309  test loss:0.973447734117508
# train loss:0.7306094246691671  test loss:0.9780430734157562
# train loss:0.6881789277339804  test loss:0.9693413197994232
# train loss:0.7339065392212621  test loss:0.9794829249382019
# train loss:0.6924973602952629  test loss:0.9695177853107453
# train loss:0.6508296265684325  test loss:0.9669134378433227
# train loss:0.6478107104013706  test loss:0.9846442580223084
# train loss:0.7476615083628687  test loss:0.9543360888957977
# train loss:0.7345639241152796  test loss:0.952451205253601
# train loss:0.6551654133303412  test loss:0.9556863367557525
# train loss:0.664840966463089  test loss:0.9516408741474152
# train loss:0.6101481078256821  test loss:0.9460187911987304
# train loss:0.6529509209353348  test loss:0.962006253004074
# train loss:0.5882461025411713  test loss:0.9284978806972504
# train loss:0.658361405134201  test loss:0.9251991093158722
# train loss:0.558041168184116  test loss:0.9587524592876434
# train loss:0.5235497355461121  test loss:0.9494167149066925
# train loss:0.6070916580742803  test loss:0.9305179297924042
# train loss:0.5609610011833238  test loss:0.9678802132606507
# train loss:0.6130924255683504  test loss:0.9710335433483124
# train loss:0.5805576597822124  test loss:0.9408222198486328
# train loss:0.544838011939207  test loss:1.0182214498519897
# train loss:0.5515964457700993  test loss:0.9312873899936676
# train loss:0.5072833351020155  test loss:0.975692766904831
# train loss:0.4760622541452276  test loss:0.9607687354087829
# train loss:0.5333337318794481  test loss:0.9440025746822357
# train loss:0.4804209388535598  test loss:0.9585842549800873
# train loss:0.5093251917639683  test loss:0.9664013862609864
# train loss:0.5249323017638305  test loss:0.9625576496124267
# train loss:0.4671259535283878  test loss:0.9919904291629791
# train loss:0.5369834365515873  test loss:0.976360160112381
# train loss:0.47395415038898075  test loss:0.8952405452728271

# %%
img,label = next(iter(test_loader))
ypred = model(img.to(device))
ypred = torch.argmax(ypred,dim=1)
ypred
# Out:
# tensor([2, 0, 0, 0, 2, 0, 0, 2], device='cuda:0')

# %%
label
# Out:
# tensor([0, 0, 0, 0, 0, 0, 0, 0])

# %%
plt.imshow(img[7].permute(1,2,0))

# %%
torch.save(model.state_dict(),'prototype7.pth')

# %%
torch.save(model,'model.pth')
